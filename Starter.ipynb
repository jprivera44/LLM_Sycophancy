# %%
# Loading in libraries
import torch

# %%
#steps

#I want to compare the activations of specific language models specifically on mistral and Llama2
#I should run the previous code, and also  do the code here for myself.

# %%
from google.colab import drive
drive.mount('gzip')
# Out:
# Mounted at gzip
